# %% [markdown]
# # Algoritmos - Actividad Guiada 1
#
# Nombre: Obed Israel Ortiz Navarrete<br>
#
# Link:   https://colab.research.google.com/drive/13wT41Se9ol58SkBBaGzxyKJEYi3SXmMs <br>
# http: [github.com/obed-ortiz/VIU_algoritmos_de_optimizacion](https://github.com/obed-ortiz/VIU_algoritmos_de_optimizacion)

# %% [markdown]
# ##Torres de Hanoi con Divide y vencerás

# %%
def Torres_Hanoi(N, desde, hasta):
  if N ==1 :
    print("Lleva la ficha " ,desde , " hasta ", hasta )

  else:
    #Torres_Hanoi(N-1, desde, 6-desde-hasta )
    Torres_Hanoi(N-1, desde, 6-desde-hasta )
    print("Lleva la ficha " ,desde , " hasta ", hasta )
    #Torres_Hanoi(N-1,6-desde-hasta, hasta )
    Torres_Hanoi(N-1, 6-desde-hasta  , hasta )


Torres_Hanoi(3, 1 , 3)
# Out:
# Lleva la ficha  1  hasta  3
# Lleva la ficha  1  hasta  2
# Lleva la ficha  3  hasta  2
# Lleva la ficha  1  hasta  3
# Lleva la ficha  2  hasta  1
# Lleva la ficha  2  hasta  3
# Lleva la ficha  1  hasta  3

# %%
#Sucesión_de_Fibonacci
#https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci
#Calculo del termino n-simo de la suscesión de Fibonacci
def Fibonacci(N:int):
  if N < 2:
    return 1
  else:
    return Fibonacci(N-1)+Fibonacci(N-2)

Fibonacci(5)
# Out:
# 8

# %% [markdown]
# <b>Aporte sucesión de Fibonacci:</b>

# %%
import time

def Fibonacci_v1(N:int):
  if N < 2:
    return 1
  else:
    return Fibonacci_v1(N-1)+Fibonacci_v1(N-2)

def Fibonacci_v2(N: int):
    if N < 2:
        return 1
    a, b = 1, 1
    for item in range(2, N + 1):
        temp = a
        a = b
        b = temp + b
    return b

def medir_tiempo(func, N):
    inicio = time.time()
    resultado = func(N)
    fin = time.time()
    duracion = fin - inicio
    return resultado, duracion

N = 40
resultado, tiempo = medir_tiempo(Fibonacci_v1, N)
print(f"Fibonacci_v1 Resultado: {resultado} - Tiempo: {tiempo:.6f} segundos")

resultado, tiempo = medir_tiempo(Fibonacci_v2, N)
print(f"Fibonacci_v2 Resultado: {resultado} - Tiempo: {tiempo:.6f} segundos")

print(f"La segunda funcion responde mucho mas rapido con numeros mayores")
# Out:
# Fibonacci_v1 Resultado: 165580141 - Tiempo: 29.233719 segundos
# Fibonacci_v2 Resultado: 165580141 - Tiempo: 0.000000 segundos
# La segunda funcion responde mucho mas rapido con numeros mayores

# %% [markdown]
# ##Devolución de cambio por técnica voraz

# %%
def cambio_monedas(N, SM):
  SOLUCION = [0]*len(SM)   #SOLUCION = [0,0,0,0,..]
  ValorAcumulado = 0

  for i,valor in enumerate(SM):
    monedas =  (N-ValorAcumulado)//valor
    SOLUCION[i] = monedas
    ValorAcumulado = ValorAcumulado + monedas*valor

    if ValorAcumulado == N:
      return SOLUCION


cambio_monedas(15,[25,10,5,1])
# Out:
# [0, 1, 1, 0]

# %% [markdown]
# <b>Aporte técnica voraz:</b>

# %% [markdown]
# Implementar cambio de monedas segun las monedas disponibles:

# %%
import copy

def cambio_monedas(N, SM):
  SOLUCION = [0]*len(SM)   #SOLUCION = [0,0,0,0,..]
  SOLUCION = [{"moneda": item["moneda"], "cantidad": 0} for item in SM]
  RESTANTE = copy.deepcopy(SM)
  ValorAcumulado = 0

  for i,valor in enumerate(SM):
    monedas = (N - ValorAcumulado) // valor['moneda']
    monedasUtilizadas = min(monedas, valor['cantidad'])
    SOLUCION[i]["cantidad"] = monedasUtilizadas
    RESTANTE[i]["cantidad"] -= monedasUtilizadas
    ValorAcumulado += monedasUtilizadas * valor['moneda']

  if ValorAcumulado < N:
        print(f"No hay suficientes monedas para cubrir el monto de {N}. Solo se pudo juntar {ValorAcumulado}.")
  else:
    print("CANTIDAD UTILIZADA")
    print(SOLUCION)
    print("----------------------------")
    print("CANTIDAD RESTANTE")
    print(RESTANTE)

cambio_monedas(70,[
    {"moneda": 25, "cantidad": 1},
    {"moneda": 10, "cantidad": 3},
    {"moneda": 5, "cantidad": 4},
    {"moneda": 1, "cantidad": 9}])
# Out:
# CANTIDAD UTILIZADA
# [{'moneda': 25, 'cantidad': 1}, {'moneda': 10, 'cantidad': 3}, {'moneda': 5, 'cantidad': 3}, {'moneda': 1, 'cantidad': 0}]
# ----------------------------
# CANTIDAD RESTANTE
# [{'moneda': 25, 'cantidad': 0}, {'moneda': 10, 'cantidad': 0}, {'moneda': 5, 'cantidad': 1}, {'moneda': 1, 'cantidad': 9}]

# %% [markdown]
# ## N-Reinas por técnica de vueta atrás

# %%
def escribe(S):
  n = len(S)
  for x in range(n):
    print("")
    for i in range(n):
      if S[i] == x+1:
        print(" X " , end="")
      else:
        print(" - ", end="")


def es_prometedora(SOLUCION,etapa):
  #print(SOLUCION)
  #Si la solución tiene dos valores iguales no es valida => Dos reinas en la misma fila
  for i in range(etapa+1):
    #print("El valor " + str(SOLUCION[i]) + " está " +  str(SOLUCION.count(SOLUCION[i])) + " veces")
    if SOLUCION.count(SOLUCION[i]) > 1:
      return False

    #Verifica las diagonales
    for j in range(i+1, etapa +1 ):
      #print("Comprobando diagonal de " + str(i) + " y " + str(j))
      if abs(i-j) == abs(SOLUCION[i]-SOLUCION[j]) : return False
  return True



def reinas(N, solucion=[], etapa=0):
  if len(solucion) == 0:
      solucion=[0 for i in range(N)]

  for i in range(1, N+1):
    solucion[etapa] = i

    if es_prometedora(solucion, etapa):
      if etapa == N-1:
        print(solucion)
        #escribe(solucion)
        print()
      else:
        reinas(N, solucion, etapa+1)
    else:
      None

    solucion[etapa] = 0

reinas(8)
# Out:
# [1, 5, 8, 6, 3, 7, 2, 4]
#
# [1, 6, 8, 3, 7, 4, 2, 5]
#
# [1, 7, 4, 6, 8, 2, 5, 3]
#
# [1, 7, 5, 8, 2, 4, 6, 3]
#
# [2, 4, 6, 8, 3, 1, 7, 5]
#
# [2, 5, 7, 1, 3, 8, 6, 4]
#
# [2, 5, 7, 4, 1, 8, 6, 3]
#
# [2, 6, 1, 7, 4, 8, 3, 5]
#
# [2, 6, 8, 3, 1, 4, 7, 5]
#
# [2, 7, 3, 6, 8, 5, 1, 4]
#
# [2, 7, 5, 8, 1, 4, 6, 3]
#
# [2, 8, 6, 1, 3, 5, 7, 4]
#
# [3, 1, 7, 5, 8, 2, 4, 6]
#
# [3, 5, 2, 8, 1, 7, 4, 6]
#
# [3, 5, 2, 8, 6, 4, 7, 1]
#
# [3, 5, 7, 1, 4, 2, 8, 6]
#
# [3, 5, 8, 4, 1, 7, 2, 6]
#
# [3, 6, 2, 5, 8, 1, 7, 4]
#
# [3, 6, 2, 7, 1, 4, 8, 5]
#
# [3, 6, 2, 7, 5, 1, 8, 4]
#
# [3, 6, 4, 1, 8, 5, 7, 2]
#
# [3, 6, 4, 2, 8, 5, 7, 1]
#
# [3, 6, 8, 1, 4, 7, 5, 2]
#
# [3, 6, 8, 1, 5, 7, 2, 4]
#
# [3, 6, 8, 2, 4, 1, 7, 5]
#
# [3, 7, 2, 8, 5, 1, 4, 6]
#
# [3, 7, 2, 8, 6, 4, 1, 5]
#
# [3, 8, 4, 7, 1, 6, 2, 5]
#
# [4, 1, 5, 8, 2, 7, 3, 6]
#
# [4, 1, 5, 8, 6, 3, 7, 2]
#
# [4, 2, 5, 8, 6, 1, 3, 7]
#
# [4, 2, 7, 3, 6, 8, 1, 5]
#
# [4, 2, 7, 3, 6, 8, 5, 1]
#
# [4, 2, 7, 5, 1, 8, 6, 3]
#
# ...

# %% [markdown]
# <b>Aporte técnica vuelta para atrás:</b>

# %% [markdown]
# Esta contribución agiliza la localización de reinas en diagonales al asignarles un identificador único. Esto elimina la necesidad de escanear todas las diagonales, haciendo la búsqueda más eficiente, especialmente con grandes conjuntos de datos.

# %%
def escribe(soluciones_encontradas, N):
  for idx, sol in enumerate(soluciones_encontradas):
        print(f"Solución {idx + 1}:")
        for fila in sol:
            print(" - " * fila + " ♛ " + " - " * (N - fila - 1))
        print("\n")

def resolver_n_reinas(N):
    solucion=[0 for i in range(N)]
    filas_ocupadas = [False] * N
    #[0]  [1]  [2]  [3]   
    #[1]  [2]  [3]  [4]   
    #[2]  [3]  [4]  [5]   
    #[3]  [4]  [5]  [6]
    # Existen 6 diagonales maximas (2*n-1)
    diag_izq_der = [False] * (2 * N - 1)  # fila + columna 

    #[3]  [4]  [5]  [6]
    #[2]  [3]  [4]  [5]
    #[1]  [2]  [3]  [4]
    #[0]  [1]  [2]  [3]
    # Existen 6 diagonales maximas (2*n-1)
    diag_der_izq = [False] * (2 * N - 1)  # columna - fila + n - 1

    soluciones_encontradas = []

    def valida_solucion(columna_actual):
        if columna_actual == N:
            soluciones_encontradas.append(solucion.copy())
            return

        for fila in range(N):
            id_diag_izq_der = columna_actual + fila # ↘ IDENTIFICA EL ID DE LA DIAGONAL
            id_diag_der_izq = columna_actual - fila + N - 1 # ↙ IDENTIFICA EL ID DE LA DIAGONAL
            valida_diagonal_der_izq = diag_der_izq[id_diag_der_izq] 
            valida_diagonal_izq_der = diag_izq_der[id_diag_izq_der] 

            # Validar que ninguna otra reina no este en la fila, ni en ninguna ID de diagonal 
            if not filas_ocupadas[fila] and not valida_diagonal_izq_der and not valida_diagonal_der_izq:
                solucion[columna_actual] = fila
                filas_ocupadas[fila] = True
                diag_izq_der[id_diag_izq_der] = True
                diag_der_izq[id_diag_der_izq] = True

                #Llamada recursiva para validar las demas columnas
                valida_solucion(columna_actual + 1)

                # Si no cumple con completar las N reinas, no es una solucion valida y se remueve (retroceder)
                filas_ocupadas[fila] = False
                diag_izq_der[columna_actual + fila] = False
                diag_der_izq[columna_actual - fila + N - 1] = False

    valida_solucion(0)
    escribe(soluciones_encontradas, N)
    

    return soluciones_encontradas


def medir_tiempo(func, N):
    inicio = time.time()
    resultado = func(N)
    fin = time.time()
    duracion = fin - inicio
    return resultado, duracion

resultado, tiempo = medir_tiempo(resolver_n_reinas, 11)
print(f"N-Reinas Tiempo: {tiempo:.6f} segundos")
# Out:
# Solución 1:
#  ♛  -  -  -  -  -  -  -  -  -  -
#  -  -  ♛  -  -  -  -  -  -  -  -
#  -  -  -  -  ♛  -  -  -  -  -  -
#  -  -  -  -  -  -  ♛  -  -  -  -
#  -  -  -  -  -  -  -  -  ♛  -  -
#  -  -  -  -  -  -  -  -  -  -  ♛
#  -  ♛  -  -  -  -  -  -  -  -  -
#  -  -  -  ♛  -  -  -  -  -  -  -
#  -  -  -  -  -  ♛  -  -  -  -  -
#  -  -  -  -  -  -  -  ♛  -  -  -
#  -  -  -  -  -  -  -  -  -  ♛  -
#
#
# Solución 2:
#  ♛  -  -  -  -  -  -  -  -  -  -
#  -  -  ♛  -  -  -  -  -  -  -  -
#  -  -  -  -  -  ♛  -  -  -  -  -
#  -  -  -  -  -  -  -  -  ♛  -  -
#  -  ♛  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  ♛  -  -  -
#  -  -  -  -  -  -  -  -  -  -  ♛
#  -  -  -  ♛  -  -  -  -  -  -  -
#  -  -  -  -  -  -  ♛  -  -  -  -
#  -  -  -  -  ♛  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  ♛  -
#
#
# Solución 3:
#  ♛  -  -  -  -  -  -  -  -  -  -
#  -  -  ♛  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  ♛  -  -  -  -
#  -  -  -  -  -  -  -  -  ♛  -  -
#  -  -  -  ♛  -  -  -  -  -  -  -
# ...

# %% [markdown]
# ## Viaje por el rio. Programación dinámica

# %%
TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]



################################################################
def Precios(TARIFAS):
################################################################
  #Total de Nodos
  N = len(TARIFAS[0])

  #Inicialización de la tabla de precios
  PRECIOS = [ [9999]*N for i in [9999]*N]
  RUTA = [ [""]*N for i in [""]*N]

  for i in range(0,N-1):
    RUTA[i][i] = i             #Para ir de i a i se "pasa por i"
    PRECIOS[i][i] = 0          #Para ir de i a i se se paga 0
    for j in range(i+1, N):
      MIN = TARIFAS[i][j]
      RUTA[i][j] = i

      for k in range(i, j):
        if PRECIOS[i][k] + TARIFAS[k][j] < MIN:
            MIN = min(MIN, PRECIOS[i][k] + TARIFAS[k][j] )
            RUTA[i][j] = k          #Anota que para ir de i a j hay que pasar por k
        PRECIOS[i][j] = MIN

  return PRECIOS,RUTA
################################################################


PRECIOS,RUTA = Precios(TARIFAS)
#print(PRECIOS[0][6])

print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")
for i in range(len(TARIFAS)):
  print(RUTA[i])

#Determinar la ruta con Recursividad
def calcular_ruta(RUTA, desde, hasta):
  if desde == hasta:
    #print("Ir a :" + str(desde))
    return ""
  else:
    return str(calcular_ruta( RUTA, desde, RUTA[desde][hasta])) +  \
                ',' + \
                str(RUTA[desde][hasta] \
              )

print("\nLa ruta es:")
calcular_ruta(RUTA, 0,6)
# Out:
# PRECIOS
# [0, 5, 4, 3, 8, 8, 11]
# [9999, 0, 999, 2, 3, 8, 7]
# [9999, 9999, 0, 1, 6, 4, 7]
# [9999, 9999, 9999, 0, 5, 6, 9]
# [9999, 9999, 9999, 9999, 0, 999, 4]
# [9999, 9999, 9999, 9999, 9999, 0, 3]
# [9999, 9999, 9999, 9999, 9999, 9999, 9999]
#
# RUTA
# [0, 0, 0, 0, 1, 2, 5]
# ['', 1, 1, 1, 1, 3, 4]
# ['', '', 2, 2, 3, 2, 5]
# ['', '', '', 3, 3, 3, 3]
# ['', '', '', '', 4, 4, 4]
# ['', '', '', '', '', 5, 5]
# ['', '', '', '', '', '', '']
#
# La ruta es:
# ',0,2,5'

# %% [markdown]
# <b>Aporte programación dinámica:</b>

# %%
TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]



################################################################
def Precios(TARIFAS):
################################################################
  #Total de Nodos
  N = len(TARIFAS)

  #Inicialización de la tabla de precios
  PRECIOS = [row[:] for row in TARIFAS] 
  RUTA = [[i if i == j or TARIFAS[i][j] < 999 else -1 for j in range(N)] for i in range(N)]

  for k in range(N):
    for i in range(N):
      if PRECIOS[i][k] == 999:
          continue  # No hay camino, podemos saltar
      for j in range(N):
          if PRECIOS[i][j] > PRECIOS[i][k] + PRECIOS[k][j]:
              PRECIOS[i][j] = PRECIOS[i][k] + PRECIOS[k][j]
              RUTA[i][j] = RUTA[k][j]              
  return PRECIOS,RUTA
################################################################


PRECIOS,RUTA = Precios(TARIFAS)
#print(PRECIOS[0][6])

print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")
for i in range(len(TARIFAS)):
  print(RUTA[i])

#Determinar la ruta con Recursividad
def calcular_ruta(RUTA, desde, hasta):
    if RUTA[desde][hasta] == -1:
        return "No hay ruta"
    if desde == hasta:
        return str(desde)
    return f"{calcular_ruta(RUTA, desde, RUTA[desde][hasta])},{hasta}"

print("\nLa ruta es:")
calcular_ruta(RUTA, 0,6)
# Out:
# PRECIOS
# [0, 5, 4, 3, 8, 8, 11]
# [999, 0, 999, 2, 3, 8, 7]
# [999, 999, 0, 1, 6, 4, 7]
# [999, 999, 999, 0, 5, 6, 9]
# [999, 999, 999, 999, 0, 999, 4]
# [999, 999, 999, 999, 999, 0, 3]
# [999, 999, 999, 999, 999, 999, 0]
#
# RUTA
# [0, 0, 0, 0, 1, 2, 5]
# [-1, 1, -1, 1, 1, 3, 4]
# [-1, -1, 2, 2, 3, 2, 5]
# [-1, -1, -1, 3, 3, 3, 3]
# [-1, -1, -1, -1, 4, -1, 4]
# [-1, -1, -1, -1, -1, 5, 5]
# [-1, -1, -1, -1, -1, -1, 6]
#
# La ruta es:
# '0,2,5,6'
